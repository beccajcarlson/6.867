# %%
##
import MySQLdb
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %%
con = MySQLdb.connect("safar.csail.mit.edu","mimic3","3CIMIM_v30","mimic3v14")

# %%
df = pd.read_sql('SELECT * FROM microbiologyevents LIMIT 100', con = con)

# %%
df
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID  CHARTDATE           CHARTTIME  SPEC_ITEMID  \
# 0        1           2   163353 2138-07-17 2138-07-17 22:10:00        70014
# 1        2           3   145834 2101-10-20 2101-10-20 13:00:00        70070
# 2        3           3   145834 2101-10-20 2101-10-20 13:00:00        70070
# 3        4           3   145834 2101-10-20 2101-10-20 13:00:00        70070
# 4        5           3   145834 2101-10-20 2101-10-20 13:00:00        70070
# 5        6           3   145834 2101-10-20 2101-10-20 18:00:00        70012
# 6        7           3   145834 2101-10-20 2101-10-20 18:30:00        70012
# 7        8           3   145834 2101-10-20                 NaT        70079
# 8        9           3   145834 2101-10-21 2101-10-21 04:00:00        70012
# 9       10           3   145834 2101-10-21 2101-10-21 04:00:00        70012
# 10      11           3   145834 2101-10-21 2101-10-21 04:15:00        70012
# ...
